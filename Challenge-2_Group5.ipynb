# %%
#Dataframe manipulation library
import pandas as pd
#Math functions, we'll only need the sqrt function so let's import only that
from math import sqrt
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### Through Feature Engineering the table has been transformed suitably for Collaborative Filtering

# %%
#reading [rec_sys_merge] table for Collaborative filtering
rec_sys_merge = pd.read_csv('train.csv')

# %%
#table shape - rows and columns
rec_sys_merge.shape
# Out:
# (7377418, 6)

# %%
#Displaying table
rec_sys_merge.head()
# Out:
#                                            msno  \
# 0  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 1  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 2  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 3  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 4  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
#
#                                         song_id source_system_tab  \
# 0  BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=           explore
# 1  bhp/MpSNoqoxOIB+/l8WPqu6jldth4DIpCm3ayXnJqM=        my library
# 2  JNWfrrC7zNN7BdMpsISKa4Mw+xVJYNnxXh3/Epw7QgY=        my library
# 3  2A87tzfnJTSWqD7gIZHisolhe4DMdzkbd6LzO1KHjNs=        my library
# 4  3qm6XTZ6MOCU11x8FIVbAGH5l5uMkT3/ZalWG1oo2Gc=           explore
#
#     source_screen_name      source_type  target
# 0              Explore  online-playlist       1
# 1  Local playlist more   local-playlist       1
# 2  Local playlist more   local-playlist       1
# 3  Local playlist more   local-playlist       1
# 4              Explore  online-playlist       1

# %%
#[Dropping the columns that they will not be used in Collaborative Filtering
#'SumAmount_PerCat_PerCust' and 'SumAmount_PerCustomer'
#they were designed in order to create the column 'proportion_spent'] part of the FEATURE ENGINEERING

to_drop_rec_sys = ['source_system_tab', 'source_screen_name']
rec_sys_merge.drop(to_drop_rec_sys, axis = 1, inplace=True)
rec_sys_merge.head()
# Out:
#                                            msno  \
# 0  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 1  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 2  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 3  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 4  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
#
#                                         song_id      source_type  target
# 0  BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=  online-playlist       1
# 1  bhp/MpSNoqoxOIB+/l8WPqu6jldth4DIpCm3ayXnJqM=   local-playlist       1
# 2  JNWfrrC7zNN7BdMpsISKa4Mw+xVJYNnxXh3/Epw7QgY=   local-playlist       1
# 3  2A87tzfnJTSWqD7gIZHisolhe4DMdzkbd6LzO1KHjNs=   local-playlist       1
# 4  3qm6XTZ6MOCU11x8FIVbAGH5l5uMkT3/ZalWG1oo2Gc=  online-playlist       1

# %%
#Limiting floats to five decimal points
#pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
rec_sys_merge.head()
# Out:
#                                            msno  \
# 0  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 1  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 2  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 3  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 4  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
#
#                                         song_id      source_type  target
# 0  BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=  online-playlist       1
# 1  bhp/MpSNoqoxOIB+/l8WPqu6jldth4DIpCm3ayXnJqM=   local-playlist       1
# 2  JNWfrrC7zNN7BdMpsISKa4Mw+xVJYNnxXh3/Epw7QgY=   local-playlist       1
# 3  2A87tzfnJTSWqD7gIZHisolhe4DMdzkbd6LzO1KHjNs=   local-playlist       1
# 4  3qm6XTZ6MOCU11x8FIVbAGH5l5uMkT3/ZalWG1oo2Gc=  online-playlist       1

# %%
#Long Tail Plot Example

import matplotlib.pyplot as plt
import recmetrics

fig = plt.figure(figsize=(15, 7))
recmetrics.long_tail_plot(df=rec_sys_merge, 
             item_id_column="song_id", 
             interaction_type="target", 
             percentage=0.5,
             x_labels=False)
# Out:
# D:\ProgramData\anaconda3\Lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10072\2630323994.py in <cell line: 0>()
#       5
#       6 fig = plt.figure(figsize=(15, 7))
# ----> 7 recmetrics.long_tail_plot(df=rec_sys_merge,
#       8              item_id_column="song_id",
#       9              interaction_type="target",
#
# D:\ProgramData\anaconda3\Lib\site-packages\recmetrics\plots.py in long_tail_plot(df, item_id_column, interaction_type, percentage, x_labels)
#      42     x=range(0,len(volume_df))
#      43     ax = sns.lineplot(x, y="volume", data=volume_df, color="black")
# ---> 44     plt.xticks(x)
#      45
#      46     #set labels
#
# D:\ProgramData\anaconda3\Lib\site-packages\matplotlib\pyplot.py in xticks(ticks, labels, minor, **kwargs)
#    1884                             "without setting 'ticks'")
#    1885     else:
# -> 1886         locs = ax.set_xticks(ticks, minor=minor)
#    1887
#    1888     if labels is None:
#
# D:\ProgramData\anaconda3\Lib\site-packages\matplotlib\axes\_base.py in wrapper(self, *args, **kwargs)
#      72
#      73         def wrapper(self, *args, **kwargs):
# ---> 74             return get_method(self)(*args, **kwargs)
#      75
#      76         wrapper.__module__ = owner.__module__
#
# D:\ProgramData\anaconda3\Lib\site-packages\matplotlib\axis.py in set_ticks(self, ticks, labels, minor, **kwargs)
#    2072             raise ValueError('labels argument cannot be None when '
#    2073                              'kwargs are passed')
# -> 2074         result = self._set_tick_locations(ticks, minor=minor)
#    2075         if labels is not None:
#    2076             self.set_ticklabels(labels, minor=minor, **kwargs)
#
# D:\ProgramData\anaconda3\Lib\site-packages\matplotlib\axis.py in _set_tick_locations(self, ticks, minor)
#    2033         else:
#    2034             self.set_major_locator(locator)
# -> 2035             return self.get_major_ticks(len(ticks))
#    2036
#    2037     def set_ticks(self, ticks, labels=None, *, minor=False, **kwargs):
#
# D:\ProgramData\anaconda3\Lib\site-packages\matplotlib\axis.py in get_major_ticks(self, numticks)
#    1602             tick = self._get_tick(major=True)
#    1603             self.majorTicks.append(tick)
# -> 1604             self._copy_tick_props(self.majorTicks[0], tick)
#    1605
#    1606         return self.majorTicks[:numticks]
#
# D:\ProgramData\anaconda3\Lib\site-packages\matplotlib\axis.py in _copy_tick_props(self, src, dest)
#    1570         dest.label2.update_from(src.label2)
#    1571         dest.tick1line.update_from(src.tick1line)
# -> 1572         dest.tick2line.update_from(src.tick2line)
#    1573         dest.gridline.update_from(src.gridline)
#    1574
#
# D:\ProgramData\anaconda3\Lib\site-packages\matplotlib\lines.py in update_from(self, other)
#    1353
#    1354         self._linestyle = other._linestyle
# -> 1355         self._marker = MarkerStyle(marker=other._marker)
#    1356         self._drawstyle = other._drawstyle
#    1357
#
# D:\ProgramData\anaconda3\Lib\site-packages\matplotlib\markers.py in __init__(self, marker, fillstyle, transform, capstyle, joinstyle)
#     270                 "%(since)s; support will be removed %(removal)s.  Use "
#     271                 "MarkerStyle('') to construct an empty MarkerStyle.")
# --> 272         self._set_marker(marker)
#     273
#     274     __init__.__signature__ = inspect.signature(  # Only for deprecation period.
#
# D:\ProgramData\anaconda3\Lib\site-packages\matplotlib\markers.py in _set_marker(self, marker)
#     353                 self, '_set_' + self.markers[marker])
#     354         elif isinstance(marker, MarkerStyle):
# --> 355             self.__dict__ = copy.deepcopy(marker.__dict__)
#     356
#     357         else:
#
# D:\ProgramData\anaconda3\Lib\copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# D:\ProgramData\anaconda3\Lib\copy.py in _deepcopy_dict(x, memo, deepcopy)
#     229     memo[id(x)] = y
#     230     for key, value in x.items():
# --> 231         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     232     return y
#     233 d[dict] = _deepcopy_dict
#
# D:\ProgramData\anaconda3\Lib\copy.py in deepcopy(x, memo, _nil)
#     151             copier = getattr(x, "__deepcopy__", None)
#     152             if copier is not None:
# --> 153                 y = copier(memo)
#     154             else:
#     155                 reductor = dispatch_table.get(cls)
#
# D:\ProgramData\anaconda3\Lib\site-packages\matplotlib\path.py in __deepcopy__(self, memo)
#     285         """
#     286         # Deepcopying arrays (vertices, codes) strips the writeable=False flag.
# --> 287         p = copy.deepcopy(super(), memo)
#     288         p._readonly = False
#     289         return p
#
# D:\ProgramData\anaconda3\Lib\copy.py in deepcopy(x, memo, _nil)
#     170                     y = x
#     171                 else:
# --> 172                     y = _reconstruct(x, memo, *rv)
#     173
#     174     # If is its own copy, don't memoize.
#
# D:\ProgramData\anaconda3\Lib\copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     269     if state is not None:
#     270         if deep:
# --> 271             state = deepcopy(state, memo)
#     272         if hasattr(y, '__setstate__'):
#     273             y.__setstate__(state)
#
# D:\ProgramData\anaconda3\Lib\copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# D:\ProgramData\anaconda3\Lib\copy.py in _deepcopy_dict(x, memo, deepcopy)
#     229     memo[id(x)] = y
#     230     for key, value in x.items():
# --> 231         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     232     return y
#     233 d[dict] = _deepcopy_dict
#
# D:\ProgramData\anaconda3\Lib\copy.py in deepcopy(x, memo, _nil)
#     151             copier = getattr(x, "__deepcopy__", None)
#     152             if copier is not None:
# --> 153                 y = copier(memo)
#     154             else:
#     155                 reductor = dispatch_table.get(cls)
#
# KeyboardInterrupt:
# Error in callback <function _draw_all_if_interactive at 0x0000013E3F293EC0> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# D:\ProgramData\anaconda3\Lib\site-packages\matplotlib\pyplot.py in _draw_all_if_interactive()
#     118 def _draw_all_if_interactive():
#     119     if matplotlib.is_interactive():
# --> 120         draw_all()
#     121
#     122
#
# D:\ProgramData\anaconda3\Lib\site-packages\matplotlib\_pylab_helpers.py in draw_all(cls, force)
#     130         for manager in cls.get_all_fig_managers():
#     131             if force or manager.canvas.figure.stale:
# --> 132                 manager.canvas.draw_idle()
#     133
#     134
#
# D:\ProgramData\anaconda3\Lib\site-packages\matplotlib\backend_bases.py in draw_idle(self, *args, **kwargs)
#    2080         if not self._is_idle_drawing:
#    2081             with self._idle_draw_cntx():
# -> 2082                 self.draw(*args, **kwargs)
#    2083
#    2084     @property
#
# D:\ProgramData\anaconda3\Lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     398              (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     399               else nullcontext()):
# --> 400             self.figure.draw(self.renderer)
#     401             # A GUI class may be need to update a window using this draw, so
#     402             # don't forget to call the superclass.
#
# D:\ProgramData\anaconda3\Lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      93     @wraps(draw)
#      94     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95         result = draw(artist, renderer, *args, **kwargs)
#      96         if renderer._rasterizing:
#      97             renderer.stop_rasterizing()
#
# D:\ProgramData\anaconda3\Lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer)
#      70                 renderer.start_filter()
#      71
# ---> 72             return draw(artist, renderer)
#      73         finally:
#      74             if artist.get_agg_filter() is not None:
#
# D:\ProgramData\anaconda3\Lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    3138
#    3139             self.patch.draw(renderer)
# -> 3140             mimage._draw_list_compositing_images(
#    3141                 renderer, self, artists, self.suppressComposite)
#    3142
#
# D:\ProgramData\anaconda3\Lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# D:\ProgramData\anaconda3\Lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer)
#      70                 renderer.start_filter()
#      71
# ---> 72             return draw(artist, renderer)
#      73         finally:
#      74             if artist.get_agg_filter() is not None:
#
# D:\ProgramData\anaconda3\Lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer)
#    3062             _draw_rasterized(self.figure, artists_rasterized, renderer)
#    3063
# -> 3064         mimage._draw_list_compositing_images(
#    3065             renderer, self, artists, self.figure.suppressComposite)
#    3066
#
# D:\ProgramData\anaconda3\Lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# D:\ProgramData\anaconda3\Lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer)
#      70                 renderer.start_filter()
#      71
# ---> 72             return draw(artist, renderer)
#      73         finally:
#      74             if artist.get_agg_filter() is not None:
#
# D:\ProgramData\anaconda3\Lib\site-packages\matplotlib\axis.py in draw(self, renderer, *args, **kwargs)
#    1374         renderer.open_group(__name__, gid=self.get_gid())
#    1375
# -> 1376         ticks_to_draw = self._update_ticks()
#    1377         tlb1, tlb2 = self._get_ticklabel_bboxes(ticks_to_draw, renderer)
#    1378
#
# D:\ProgramData\anaconda3\Lib\site-packages\matplotlib\axis.py in _update_ticks(self)
#    1262         major_locs = self.get_majorticklocs()
#    1263         major_labels = self.major.formatter.format_ticks(major_locs)
# -> 1264         major_ticks = self.get_major_ticks(len(major_locs))
#    1265         self.major.formatter.set_locs(major_locs)
#    1266         for tick, loc, label in zip(major_ticks, major_locs, major_labels):
#
# D:\ProgramData\anaconda3\Lib\site-packages\matplotlib\axis.py in get_major_ticks(self, numticks)
#    1600         while len(self.majorTicks) < numticks:
#    1601             # Update the new tick label properties from the old.
# -> 1602             tick = self._get_tick(major=True)
#    1603             self.majorTicks.append(tick)
#    1604             self._copy_tick_props(self.majorTicks[0], tick)
#
# D:\ProgramData\anaconda3\Lib\site-packages\matplotlib\axis.py in _get_tick(self, major)
#    1549                 "_tick_class or reimplement _get_tick()")
#    1550         tick_kw = self._major_tick_kw if major else self._minor_tick_kw
# -> 1551         return self._tick_class(self.axes, 0, major=major, **tick_kw)
#    1552
#    1553     def _get_tick_label_size(self, axis_name):
#
# D:\ProgramData\anaconda3\Lib\site-packages\matplotlib\axis.py in __init__(self, *args, **kwargs)
#     415
#     416     def __init__(self, *args, **kwargs):
# --> 417         super().__init__(*args, **kwargs)
#     418         # x in data coords, y in axes coords
#     419         ax = self.axes
#
# D:\ProgramData\anaconda3\Lib\site-packages\matplotlib\axis.py in __init__(self, axes, loc, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kwargs)
#     181             rotation=self._labelrotation[1])
#     182
# --> 183         self._apply_tickdir(tickdir)
#     184
#     185         for artist in [self.tick1line, self.tick2line, self.gridline,
#
# D:\ProgramData\anaconda3\Lib\site-packages\matplotlib\axis.py in _apply_tickdir(self, tickdir)
#     450             'inout': ('|', '|'),
#     451         }[self._tickdir]
# --> 452         self.tick1line.set_marker(mark1)
#     453         self.tick2line.set_marker(mark2)
#     454
#
# D:\ProgramData\anaconda3\Lib\site-packages\matplotlib\lines.py in set_marker(self, marker)
#    1191             arguments.
#    1192         """
# -> 1193         self._marker = MarkerStyle(marker, self._marker.get_fillstyle())
#    1194         self.stale = True
#    1195
#
# D:\ProgramData\anaconda3\Lib\site-packages\matplotlib\markers.py in __init__(self, marker, fillstyle, transform, capstyle, joinstyle)
#     270                 "%(since)s; support will be removed %(removal)s.  Use "
#     271                 "MarkerStyle('') to construct an empty MarkerStyle.")
# --> 272         self._set_marker(marker)
#     273
#     274     __init__.__signature__ = inspect.signature(  # Only for deprecation period.
#
# D:\ProgramData\anaconda3\Lib\site-packages\matplotlib\markers.py in _set_marker(self, marker)
#     365         if not isinstance(marker, MarkerStyle):
#     366             self._marker = marker
# --> 367             self._recache()
#     368
#     369     def get_path(self):
#
# D:\ProgramData\anaconda3\Lib\site-packages\matplotlib\markers.py in _recache(self)
#     289         # markers.
#     290         self._filled = self._fillstyle != 'none'
# --> 291         self._marker_function()
#     292
#     293     def __bool__(self):
#
# D:\ProgramData\anaconda3\Lib\site-packages\matplotlib\markers.py in _set_tickdown(self)
#     810
#     811     def _set_tickdown(self):
# --> 812         self._transform = Affine2D().scale(1.0, -1.0)
#     813         self._snap_threshold = 1.0
#     814         self._filled = False
#
# D:\ProgramData\anaconda3\Lib\site-packages\matplotlib\transforms.py in __init__(self, matrix, **kwargs)
#    1893             # A bit faster than np.identity(3).
#    1894             matrix = IdentityTransform._mtx
# -> 1895         self._mtx = matrix.copy()
#    1896         self._invalid = 0
#    1897
#
# KeyboardInterrupt:
# Error in callback <function flush_figures at 0x0000013E3F5F6020> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# D:\ProgramData\anaconda3\Lib\site-packages\matplotlib_inline\backend_inline.py in flush_figures()
#     124             # ignore the tracking, just draw and close all figures
#     125             try:
# --> 126                 return show(True)
#     127             except Exception as e:
#     128                 # safely show traceback if in IPython, else raise
#
# D:\ProgramData\anaconda3\Lib\site-packages\matplotlib_inline\backend_inline.py in show(close, block)
#      88     try:
#      89         for figure_manager in Gcf.get_all_fig_managers():
# ---> 90             display(
#      91                 figure_manager.canvas.figure,
#      92                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# ~\AppData\Roaming\Python\Python311\site-packages\IPython\core\display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     318             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     319         else:
# --> 320             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     321             if not format_dict:
#     322                 # nothing to display (e.g. _ipython_display_ took over)
#
# ~\AppData\Roaming\Python\Python311\site-packages\IPython\core\formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# D:\ProgramData\anaconda3\Lib\site-packages\decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# ~\AppData\Roaming\Python\Python311\site-packages\IPython\core\formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# ~\AppData\Roaming\Python\Python311\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149         FigureCanvasBase(fig)
#     150
# --> 151     fig.canvas.print_figure(bytes_io, **kw)
#     152     data = bytes_io.getvalue()
#     153     if fmt == 'svg':
#
# D:\ProgramData\anaconda3\Lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2340                 )
#    2341                 with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2342                     self.figure.draw(renderer)
#    2343
#    2344             if bbox_inches:
#
# D:\ProgramData\anaconda3\Lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      93     @wraps(draw)
#      94     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95         result = draw(artist, renderer, *args, **kwargs)
#      96         if renderer._rasterizing:
#      97             renderer.stop_rasterizing()
#
# D:\ProgramData\anaconda3\Lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer)
#      70                 renderer.start_filter()
#      71
# ---> 72             return draw(artist, renderer)
#      73         finally:
#      74             if artist.get_agg_filter() is not None:
#
# D:\ProgramData\anaconda3\Lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    3138
#    3139             self.patch.draw(renderer)
# -> 3140             mimage._draw_list_compositing_images(
#    3141                 renderer, self, artists, self.suppressComposite)
#    3142
#
# D:\ProgramData\anaconda3\Lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# D:\ProgramData\anaconda3\Lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer)
#      70                 renderer.start_filter()
#      71
# ---> 72             return draw(artist, renderer)
#      73         finally:
#      74             if artist.get_agg_filter() is not None:
#
# D:\ProgramData\anaconda3\Lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer)
#    3062             _draw_rasterized(self.figure, artists_rasterized, renderer)
#    3063
# -> 3064         mimage._draw_list_compositing_images(
#    3065             renderer, self, artists, self.figure.suppressComposite)
#    3066
#
# D:\ProgramData\anaconda3\Lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# D:\ProgramData\anaconda3\Lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer)
#      70                 renderer.start_filter()
#      71
# ---> 72             return draw(artist, renderer)
#      73         finally:
#      74             if artist.get_agg_filter() is not None:
#
# D:\ProgramData\anaconda3\Lib\site-packages\matplotlib\axis.py in draw(self, renderer, *args, **kwargs)
#    1374         renderer.open_group(__name__, gid=self.get_gid())
#    1375
# -> 1376         ticks_to_draw = self._update_ticks()
#    1377         tlb1, tlb2 = self._get_ticklabel_bboxes(ticks_to_draw, renderer)
#    1378
#
# D:\ProgramData\anaconda3\Lib\site-packages\matplotlib\axis.py in _update_ticks(self)
#    1262         major_locs = self.get_majorticklocs()
#    1263         major_labels = self.major.formatter.format_ticks(major_locs)
# -> 1264         major_ticks = self.get_major_ticks(len(major_locs))
#    1265         self.major.formatter.set_locs(major_locs)
#    1266         for tick, loc, label in zip(major_ticks, major_locs, major_labels):
#
# D:\ProgramData\anaconda3\Lib\site-packages\matplotlib\axis.py in get_major_ticks(self, numticks)
#    1602             tick = self._get_tick(major=True)
#    1603             self.majorTicks.append(tick)
# -> 1604             self._copy_tick_props(self.majorTicks[0], tick)
#    1605
#    1606         return self.majorTicks[:numticks]
#
# D:\ProgramData\anaconda3\Lib\site-packages\matplotlib\axis.py in _copy_tick_props(self, src, dest)
#    1570         dest.label2.update_from(src.label2)
#    1571         dest.tick1line.update_from(src.tick1line)
# -> 1572         dest.tick2line.update_from(src.tick2line)
#    1573         dest.gridline.update_from(src.gridline)
#    1574
#
# D:\ProgramData\anaconda3\Lib\site-packages\matplotlib\lines.py in update_from(self, other)
#    1353
#    1354         self._linestyle = other._linestyle
# -> 1355         self._marker = MarkerStyle(marker=other._marker)
#    1356         self._drawstyle = other._drawstyle
#    1357
#
# D:\ProgramData\anaconda3\Lib\site-packages\matplotlib\markers.py in __init__(self, marker, fillstyle, transform, capstyle, joinstyle)
#     270                 "%(since)s; support will be removed %(removal)s.  Use "
#     271                 "MarkerStyle('') to construct an empty MarkerStyle.")
# --> 272         self._set_marker(marker)
#     273
#     274     __init__.__signature__ = inspect.signature(  # Only for deprecation period.
#
# D:\ProgramData\anaconda3\Lib\site-packages\matplotlib\markers.py in _set_marker(self, marker)
#     353                 self, '_set_' + self.markers[marker])
#     354         elif isinstance(marker, MarkerStyle):
# --> 355             self.__dict__ = copy.deepcopy(marker.__dict__)
#     356
#     357         else:
#
# D:\ProgramData\anaconda3\Lib\copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# D:\ProgramData\anaconda3\Lib\copy.py in _deepcopy_dict(x, memo, deepcopy)
#     229     memo[id(x)] = y
#     230     for key, value in x.items():
# --> 231         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     232     return y
#     233 d[dict] = _deepcopy_dict
#
# D:\ProgramData\anaconda3\Lib\copy.py in deepcopy(x, memo, _nil)
#     151             copier = getattr(x, "__deepcopy__", None)
#     152             if copier is not None:
# --> 153                 y = copier(memo)
#     154             else:
#     155                 reductor = dispatch_table.get(cls)
#
# D:\ProgramData\anaconda3\Lib\site-packages\matplotlib\path.py in __deepcopy__(self, memo)
#     285         """
#     286         # Deepcopying arrays (vertices, codes) strips the writeable=False flag.
# --> 287         p = copy.deepcopy(super(), memo)
#     288         p._readonly = False
#     289         return p
#
# D:\ProgramData\anaconda3\Lib\copy.py in deepcopy(x, memo, _nil)
#     170                     y = x
#     171                 else:
# --> 172                     y = _reconstruct(x, memo, *rv)
#     173
#     174     # If is its own copy, don't memoize.
#
# D:\ProgramData\anaconda3\Lib\copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     269     if state is not None:
#     270         if deep:
# --> 271             state = deepcopy(state, memo)
#     272         if hasattr(y, '__setstate__'):
#     273             y.__setstate__(state)
#
# D:\ProgramData\anaconda3\Lib\copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# D:\ProgramData\anaconda3\Lib\copy.py in _deepcopy_dict(x, memo, deepcopy)
#     229     memo[id(x)] = y
#     230     for key, value in x.items():
# --> 231         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     232     return y
#     233 d[dict] = _deepcopy_dict
#
# D:\ProgramData\anaconda3\Lib\copy.py in deepcopy(x, memo, _nil)
#     151             copier = getattr(x, "__deepcopy__", None)
#     152             if copier is not None:
# --> 153                 y = copier(memo)
#     154             else:
#     155                 reductor = dispatch_table.get(cls)
#
# KeyboardInterrupt:

# %% [markdown]
# ### COLLABORATIVE FILTERING

# %% [markdown]
# __Recommendation systems__ are a collection of algorithms used to recommend items to users based on information taken from the user. These systems have become ubiquitous and they can be commonly seen in online stores, movies databases and job finders.
# In the following commands of this notebook, I will explore recommendation systems based on __Collaborative Filtering__ and implement simple version of one using Python and the Pandas library.

# %% [markdown]
# The thechnique of __Collaborative Filtering__, is also known as __User-User Filtering__. As hinted by its alternate name, this technique uses other users to recommend items to the input user. It attempts to find users that have similar preferences and opinions as the input and then recommends items that they have liked to the input. There are several methods of finding similar users (Even some making use of Machine Learning), and the one I will be using here is going to be based on the __Pearson Correlation Function__.

# %% [markdown]
# __The process for creating a User Based recommendation system is as follows:__
#
# - Select a user with the categories the user has transacted
# - Based on his spend to categories, find the top X neighbours
# - Get the spend category record of the user for each neighbour.
# - Calculate a similarity score using some formula
# - Recommend the items with the highest score
#
#
# I begin by creating an __input user__ to recommend Categories to:
#
# Note: Adding more categories, simply by increasing the amount of (category) elements in the userInput.

# %%
#userInput = [
#            {'category':'Agricultural Services', 'proportion_spent':0.0192},
#            {'category':'Business Services', 'proportion_spent':47.8142},
#            {'category':'Miscellaneous Stores', 'proportion_spent':1.5572},
#            {'category':'Retail Outlet Services', 'proportion_spent':0.2654000000000001} 
#          ] 
#inputCategories = pd.DataFrame(userInput)
#inputCategories

# %%
#Creating an input user/customer to recommend categories 
#The input user has customer_id: '227714a3-e0a9-4260-8d67-fc22665b4992' 
#The ** number of transactions ** that are associated with the input user is equal to 313 transactions.

#userInput = [
#            {'category':'Agricultural Services', 'proportion_spent':0.209110},
#            {'category':'Business Services', 'proportion_spent':0.082534},
#            {'category':'Clothing Stores', 'proportion_spent':0.051550},
#            {'category':'Miscellaneous Stores', 'proportion_spent':0.491298},
#            {'category':'Retail Outlet Services', 'proportion_spent':0.165508} 
#          ] 
#inputCategories = pd.DataFrame(userInput)
#inputCategories

# %%
is_mycust = rec_sys_merge['msno']=='FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg='    #'00015fc4-6fdc-4120-be42-a49e8bbe8cce', '0016ee8d-e2d6-4dd9-9559-3be13e9f53b5'
print(is_mycust.head())
rec_sys_merge_is_mycust = rec_sys_merge[is_mycust]
print(rec_sys_merge_is_mycust.shape)
display(rec_sys_merge_is_mycust)
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4     True
# Name: msno, dtype: bool
# (5511, 4)
#                                                  msno  \
# 0        FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 4        FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 5        FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 7        FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 6721     FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# ...                                               ...
# 7351223  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 7353615  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 7353617  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 7353619  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 7376785  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
#
#                                               song_id      source_type  target
# 0        BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=  online-playlist       1
# 4        3qm6XTZ6MOCU11x8FIVbAGH5l5uMkT3/ZalWG1oo2Gc=  online-playlist       1
# 5        3Hg5kugV1S0wzEVLAEfqjIV5UHzb7bCrdBRQlGygLvU=  online-playlist       1
# 7        bPIvRTzfHxH5LgHrStll+tYwSQNVV8PySgA3M1PfTgc=  online-playlist       1
# 6721     XUz4Z4wPPChz+OIwkwj7HJ8teIjW3rEMdEATM80rDxM=  online-playlist       1
# ...                                               ...              ...     ...
# 7351223  bCv44kWOnfTwkj2qg8RTnNvi+cCXrahngqDrmjIyd2o=            radio       0
# 7353615  +BuoFaAw+sbIYkgPW7ReKkPQpJbW9zvT8+UU3bU7iKU=            radio       0
# 7353617  +ChJrJNQu/z9JLoAyhielYRDiG99yhzo9m5CzQNCOD8=            radio       0
# 7353619  X8uGX+w3qTMTG8S5wauveoBnE81OP99ywklEVcXRHYE=            radio       0
# 7376785  EqYh4qmg9eB2KwGxe/I7up9+BTe+hEmQIZ2zJHWvn4Y=            radio       0
#
# [5511 rows x 4 columns]

# %%
#Creating an input user/customer to recommend categories 
#The input user has customer_id: '227714a3-e0a9-4260-8d67-fc22665b4992' 
#The number of transactions that are associated with the input user is equal to 313 transactions.

userInput = [
            {'source_type':'online-playlist', 'target':1},
            {'source_type':'local-playlist', 'target':1},
            {'source_type':'radio', 'target':0}
          ] 
inputCategories = pd.DataFrame(userInput)
inputCategories
# Out:
#        source_type  target
# 0  online-playlist       1
# 1   local-playlist       1
# 2            radio       0

# %%
#shape
inputCategories.shape
# Out:
# (3, 2)

# %%
#Filtering out the categories by master-name-category - I create the inputId variable-table which has shape [rows(20,139) , columns 4]
inputId = rec_sys_merge[rec_sys_merge['source_type'].isin(inputCategories['source_type'].tolist())]

#Then merging it so we can get the categoryId. It's implicitly merging it by category.
inputCategories = pd.merge(inputId, inputCategories)

#Dropping information we won't use from the input dataframe
inputCategories = inputCategories.drop('msno', 1)

#Final input dataframe
#If a category I added in above isn't here, then it might not be in the original 
#dataframe or it might spelled differently, check capitalisation.
inputCategories
# Out:
# C:\Users\Shubham Gupta\AppData\Local\Temp\ipykernel_10072\2450207645.py:8: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   inputCategories = inputCategories.drop('msno', 1)
#                                               song_id      source_type  target
# 0        BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=  online-playlist       1
# 1        3qm6XTZ6MOCU11x8FIVbAGH5l5uMkT3/ZalWG1oo2Gc=  online-playlist       1
# 2        3Hg5kugV1S0wzEVLAEfqjIV5UHzb7bCrdBRQlGygLvU=  online-playlist       1
# 3        bPIvRTzfHxH5LgHrStll+tYwSQNVV8PySgA3M1PfTgc=  online-playlist       1
# 4        gAsKceTstGBoPKWib6Zp0h8m15fH/qFwlfWsr24KFRg=  online-playlist       1
# ...                                               ...              ...     ...
# 1923297  GG00MjWxQ2C6WVD/W12G0kvYD1c+w+E6CSqA4SwkUo4=            radio       0
# 1923298  oiQIBoNqkCpCM88sw1HUKTO1Da3YyRhfl+thBFAmHh8=            radio       0
# 1923299  DVZgBqxIrHDx8hEZHidQd1e4mxmPX7C0sirULOFxuEY=            radio       0
# 1923300  OC7AM4DvNklFkYexaUMSCla6gvYVPbJe3Gct5+gIGCo=            radio       0
# 1923301  iiV+eezD096rVBu5m5oKwbLpKcmyI7+/wyNv+rH0d9k=            radio       0
#
# [1923302 rows x 3 columns]

# %%
inputCategories.shape
# Out:
# (1923302, 3)

# %% [markdown]
# #### The customers who has transacted in the same categories
#
# Now with the category ID's in our input, I can now get the subset of users that are interested and have made transactions in the categories in our input.

# %%
#Filtering out customers that have made transaction in the categories that the input has also transacted and storing it
userSubset = rec_sys_merge[rec_sys_merge['song_id'].isin(inputCategories['song_id'].tolist())]
userSubset.head()
# Out:
#                                            msno  \
# 0  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 1  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 2  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 3  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 4  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
#
#                                         song_id      source_type  target
# 0  BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=  online-playlist       1
# 1  bhp/MpSNoqoxOIB+/l8WPqu6jldth4DIpCm3ayXnJqM=   local-playlist       1
# 2  JNWfrrC7zNN7BdMpsISKa4Mw+xVJYNnxXh3/Epw7QgY=   local-playlist       1
# 3  2A87tzfnJTSWqD7gIZHisolhe4DMdzkbd6LzO1KHjNs=   local-playlist       1
# 4  3qm6XTZ6MOCU11x8FIVbAGH5l5uMkT3/ZalWG1oo2Gc=  online-playlist       1

# %%
#Groupby creates several sub dataframes where they all have the same value in the column specified as the parameter
userSubsetGroup = userSubset.groupby(['msno'])

# %%
#let's look at one of the customers, e.g. the one with customer_id='***...ab402e'
userSubsetGroup.get_group('FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=')
# Out:
#                                                  msno  \
# 0        FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 4        FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 5        FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 7        FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 6721     FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# ...                                               ...
# 7351223  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 7353615  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 7353617  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 7353619  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 7376785  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
#
#                                               song_id      source_type  target
# 0        BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=  online-playlist       1
# 4        3qm6XTZ6MOCU11x8FIVbAGH5l5uMkT3/ZalWG1oo2Gc=  online-playlist       1
# 5        3Hg5kugV1S0wzEVLAEfqjIV5UHzb7bCrdBRQlGygLvU=  online-playlist       1
# 7        bPIvRTzfHxH5LgHrStll+tYwSQNVV8PySgA3M1PfTgc=  online-playlist       1
# 6721     XUz4Z4wPPChz+OIwkwj7HJ8teIjW3rEMdEATM80rDxM=  online-playlist       1
# ...                                               ...              ...     ...
# 7351223  bCv44kWOnfTwkj2qg8RTnNvi+cCXrahngqDrmjIyd2o=            radio       0
# 7353615  +BuoFaAw+sbIYkgPW7ReKkPQpJbW9zvT8+UU3bU7iKU=            radio       0
# 7353617  +ChJrJNQu/z9JLoAyhielYRDiG99yhzo9m5CzQNCOD8=            radio       0
# 7353619  X8uGX+w3qTMTG8S5wauveoBnE81OP99ywklEVcXRHYE=            radio       0
# 7376785  EqYh4qmg9eB2KwGxe/I7up9+BTe+hEmQIZ2zJHWvn4Y=            radio       0
#
# [5044 rows x 4 columns]

# %% [markdown]
# __Let's also sort these groups so the users that share the most categories in common with the input have higher priority. This provides a richer recommendation since we won't go through every single user.__

# %%
#Sorting it so Customers with categories most in common with the input customer will have priority
userSubsetGroup = sorted(userSubsetGroup,  key=lambda x: len(x[1]), reverse=True)
# Out:
# C:\Users\Shubham Gupta\AppData\Local\Temp\ipykernel_10072\2431686936.py:2: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   userSubsetGroup = sorted(userSubsetGroup,  key=lambda x: len(x[1]), reverse=True)

# %%
userSubsetGroup[0:3]
# Out:
# [('MXIMDXO0j3UpaT7FvOSGW6Y5zfhlh+xYjTqGoUdMzEE=',
#                                                    msno  \
#   5656     MXIMDXO0j3UpaT7FvOSGW6Y5zfhlh+xYjTqGoUdMzEE=
#   5657     MXIMDXO0j3UpaT7FvOSGW6Y5zfhlh+xYjTqGoUdMzEE=
#   5659     MXIMDXO0j3UpaT7FvOSGW6Y5zfhlh+xYjTqGoUdMzEE=
#   12544    MXIMDXO0j3UpaT7FvOSGW6Y5zfhlh+xYjTqGoUdMzEE=
#   12545    MXIMDXO0j3UpaT7FvOSGW6Y5zfhlh+xYjTqGoUdMzEE=
#   ...                                               ...
#   7341969  MXIMDXO0j3UpaT7FvOSGW6Y5zfhlh+xYjTqGoUdMzEE=
#   7341970  MXIMDXO0j3UpaT7FvOSGW6Y5zfhlh+xYjTqGoUdMzEE=
#   7341971  MXIMDXO0j3UpaT7FvOSGW6Y5zfhlh+xYjTqGoUdMzEE=
#   7345795  MXIMDXO0j3UpaT7FvOSGW6Y5zfhlh+xYjTqGoUdMzEE=
#   7345796  MXIMDXO0j3UpaT7FvOSGW6Y5zfhlh+xYjTqGoUdMzEE=
#
#                                                 song_id      source_type  target
#   5656     U9kojfZSKaiWOW94PKh1Riyv/zUWxmBRmv0XInQWLGw=  online-playlist       1
#   5657     reXuGcEWDDCnL0K3Th//3DFG4S1ACSpJMzA+CFipo1g=  online-playlist       1
#   5659     nHr25h3r9uEiX21mU+hJuXhbZUDIZ19z638lGn458hg=  online-playlist       0
#   12544    mPfvuBngmcJEuQHhIFSTSO/46BDiQ4sPRJoWipd+ggA=  online-playlist       0
#   12545    8lGxKW1C1//LB32ChXt1tRFxD84VbA0Q9MlPJy96A8Y=  online-playlist       1
#   ...                                               ...              ...     ...
#   7341969  D9axR1eP5amyek6qeshFoy7uKTY+qOqR3ZfZarpGnlg=   local-playlist       0
#   7341970  UutQ7NDi8hnFeuP1lSQK5GUxAegxCpI73eiB6p8wkhQ=   local-playlist       0
#   88050    wfSboJwFBF6YyVmGO0wCeRtMdrqwkOgwPHV+YmSUl5Y=  online-playlist       1
#   ...                                               ...              ...     ...
#   7374677  G/QebPDDJui3OhdP+m9w1oBvohm5jaQtV071PJ3MBLY=    local-library       0
#   7375152  TIBAxLJKhN+hFEHfhHctNeiXDqS+/wEsbF76xQ9St2s=    local-library       1
#   7375153  rs6vr0QtClmnuXvsrzW7wM8ciWbPlN/5ObPu5N6LLRQ=    local-library       0
#   7376105  NmT1LR1t91uPhVkyskTBlP/drVsoxvKFC6D7L95ZXD0=    local-library       0
#   7376988  0HdxIGn+du6j5RTDdqm5JmnqZIzfpI2FkWSzrk0AXfU=    local-library       0
#
#   [4430 rows x 4 columns])]

# %% [markdown]
# #### Similarity of users to input user
# Next, I am going to compare all users (not really all !!!) to our specified user and find the one that is most similar.
# I am going to find out how similar each user is to the input through the __Pearson Correlation Coefficient__. It is used to measure the strength of a linear association between two variables. The formula for finding this coefficient between sets X and Y with N values can be seen below.
#
# Why Pearson Correlation?
#
# Pearson correlation is invariant to scaling, i.e. multiplying all elements by a nonzero constant or adding any constant to all elements. For example, if you have two vectors X and Y,then, pearson(X, Y) == pearson(X, 2 * Y + 3). This is a pretty important property in recommendation systems because for example two users might spend in two series of categories totally different amount in terms of absolute amount, but they would be similar users (i.e. with similar ideas) with similar spending in various scales .
#
# ![alt text](https://wikimedia.org/api/rest_v1/media/math/render/svg/bd1ccc2979b0fd1c1aec96e386f686ae874f9ec0 "Pearson Correlation")
#
# The values given by the formula vary from r = -1 to r = 1, where 1 forms a direct correlation between the two entities (it means a perfect positive correlation) and -1 forms a perfect negative correlation.
#
# In our case, a 1 means that the two users have similar tastes while a -1 means the opposite.

# %%
#selecting a subset of users to iterate through. 
#This limit is imposed because we don't want to waste too much time going through every single user.

userSubsetGroup = userSubsetGroup[0:100]

# %% [markdown]
# Calculating the __Pearson Correlation__ between _input user_ and _subset group_, and __store it in a dictionary__, where the _key_ is the _user Id_ and the _value_ is the _coefficient_.

# %%
#Storing the Pearson Correlation in a dictionary, where the key is the user Id and the value is the coefficient
pearsonCorrelationDict = {}

# %%
#For every customer group in my subset
for name, group in userSubsetGroup:
    #Let's start by sorting the input and current user group so the values aren't mixed up later on
    group = group.sort_values(by='song_id')
    inputCategories = inputCategories.sort_values(by='song_id')
    #Get the N for the formula
    nSpendings = len(group)
    #Get the proportion of spending scores for the categories that they both have in common
    temp_df = inputCategories[inputCategories['song_id'].isin(group['song_id'].tolist())]
    #And then store them in a temporary buffer variable in a list format to facilitate future calculations
    tempSpendingList = temp_df['target'].tolist()
    #Putting the current user group spendings in a list format
    tempGroupList = group['target'].tolist()
    #Now let's calculate the pearson correlation between two users, so called, x and y
    Sxx = sum([i**2 for i in tempSpendingList]) - pow(sum(tempSpendingList),2)/float(nSpendings)
    Syy = sum([i**2 for i in tempGroupList]) - pow(sum(tempGroupList),2)/float(nSpendings)
    Sxy = sum( i*j for i, j in zip(tempSpendingList, tempGroupList)) - sum(tempSpendingList)*sum(tempGroupList)/float(nSpendings)
    
    #If the denominator is different than zero, then divide, else, 0 correlation.
    if Sxx != 0 and Syy != 0:
        pearsonCorrelationDict[name] = Sxy/np.sqrt(Sxx*Syy)
W8bwsiSc=', nan), ('EDSn8rAs8qjUvqhhFG5diTbaVbJi8qkoKXeMzf2JGVQ=', nan), ('FG+WikEK8x1GZIB4E2keTq2SJX4bXjFjG5gkjc8qbcw=', nan), ('QDvq4xn7ZSBkamVnc8nL672oxKVqcR2zdgRGQf0giXs=', nan), ('1wiu2UfN0BNhHfPTrDS3S/rQkX/vnwDoKH6ODTUdH9k=', nan), ('lfK5QUAaa28niDIyQ2oGkSntvSe7G5EmQ1N6nvnE8lY=', nan), ('2LbejuZF550yFLDXLIBw3gd/c462BIJ+S/SOwneSXUM=', nan), ('OOETiYOFhuTowtgRUIiKommGv0eo6XUHLc1ofgwcJew=', nan), ('NzxFYmHEK32NaephTO2QGtxiR93Cf7U/Tp6jkoY25WE=', nan), ('vBNHobQRQsofef7+9NZk4C6Y6T ...

# %%
pearsonDF = pd.DataFrame.from_dict(pearsonCorrelationDict, orient='index')
pearsonDF.columns = ['similarityIndex']
pearsonDF['msno'] = pearsonDF.index
pearsonDF.index = range(len(pearsonDF))
pearsonDF.head() #shows 100 customers by not implementing [.head()] - specified previously: userSubsetGroup[0:100]
# Out:
#    similarityIndex                                          msno
# 0              NaN  MXIMDXO0j3UpaT7FvOSGW6Y5zfhlh+xYjTqGoUdMzEE=
# 1              NaN  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 2              NaN  o+5RNlSWrzvrphgBNGIo1FLkGxBgyICns6qXj3nS7Pk=
# 3              NaN  KGXNZ/H3VxvET/+rGxlrAe7Gpz2eKMXyuSg3xh8Ij1M=
# 4              NaN  hYJpPvGod6vy09TnlXdQe3Q0vlxju5u5Ruf8V2XkTio=

# %% [markdown]
# The top x similar users to input user
#
# __Getting the top 50 users that are most similar to the input.__

# %%
#sorting the values: top 50 users that are most similar to the input

topCustomers=pearsonDF.sort_values(by='similarityIndex', ascending=False)[0:50]
topCustomers.head(10)
# Out:
#    similarityIndex                                          msno
# 0              NaN  MXIMDXO0j3UpaT7FvOSGW6Y5zfhlh+xYjTqGoUdMzEE=
# 1              NaN  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 2              NaN  o+5RNlSWrzvrphgBNGIo1FLkGxBgyICns6qXj3nS7Pk=
# 3              NaN  KGXNZ/H3VxvET/+rGxlrAe7Gpz2eKMXyuSg3xh8Ij1M=
# 4              NaN  hYJpPvGod6vy09TnlXdQe3Q0vlxju5u5Ruf8V2XkTio=
# 5              NaN  dU4RbzpIRRd/EkA9Xncpy9CglzDBZp7nKMfdnfr3Aj8=
# 6              NaN  SZ5NNypqaTWljFO1HiVZwkw3713+rM9x/JNdJd8/fzc=
# 7              NaN  cqjRBV/jWN2ujhc+z/4tz+Mj6xEfflAAt6qBXCqxKvw=
# 8              NaN  frZtrrN1Y2ZqZX3VFiq7FpAvLth3kZJNovT9cmyn2O4=
# 9              NaN  JkQacE3rvmhh65R04eDLbu+M7MCkpzmHwMGrbZo0puc=

# %% [markdown]
# ### Let's start recommending __Categories__ to the input user.

# %% [markdown]
# Spending of selected customers to all categories
#
# Going to do this by taking the __weighted average of the 'Proportion Spent'__ of the categories using the Pearson Correlation as the weight. But to do this, I first need to get the _Categories_ by the customers in the ___pearsonDF___ from the _res_sys_df_ dataframe and then store their correlation in a new column called _"similarityIndex"_. This is achieved below by merging of these two tables.

# %%
#Merging of these two tables - 'topCustomers' and 'rec_sys_df'

topUsersSpending=topCustomers.merge(rec_sys_merge, left_on='msno', right_on='msno', how='inner')
topUsersSpending.head()
# Out:
#    similarityIndex                                          msno  \
# 0              NaN  MXIMDXO0j3UpaT7FvOSGW6Y5zfhlh+xYjTqGoUdMzEE=
# 1              NaN  MXIMDXO0j3UpaT7FvOSGW6Y5zfhlh+xYjTqGoUdMzEE=
# 2              NaN  MXIMDXO0j3UpaT7FvOSGW6Y5zfhlh+xYjTqGoUdMzEE=
# 3              NaN  MXIMDXO0j3UpaT7FvOSGW6Y5zfhlh+xYjTqGoUdMzEE=
# 4              NaN  MXIMDXO0j3UpaT7FvOSGW6Y5zfhlh+xYjTqGoUdMzEE=
#
#                                         song_id      source_type  target
# 0  U9kojfZSKaiWOW94PKh1Riyv/zUWxmBRmv0XInQWLGw=  online-playlist       1
# 1  reXuGcEWDDCnL0K3Th//3DFG4S1ACSpJMzA+CFipo1g=  online-playlist       1
# 2  nHr25h3r9uEiX21mU+hJuXhbZUDIZ19z638lGn458hg=  online-playlist       0
# 3  mPfvuBngmcJEuQHhIFSTSO/46BDiQ4sPRJoWipd+ggA=  online-playlist       0
# 4  8lGxKW1C1//LB32ChXt1tRFxD84VbA0Q9MlPJy96A8Y=  online-playlist       1

# %% [markdown]
# Now all we need to do is simply multiply the category's __proportion_spent__ by its weight ___(The similarity index)___, then sum up the new proportion_spent and divide it by the sum of the weights.
#
# This can be easily done by simply multiplying the two columns, then grouping up the dataframe by categoryId and then dividing the two columns:
#
# It shows the idea of all similar users to candidate categories for the input user:

# %%
#Multiplies the similarity by the customer's proportion_spent (per master category)

topUsersSpending['weightedRating'] = topUsersSpending['similarityIndex']*topUsersSpending['target']
topUsersSpending.head()
# Out:
#    similarityIndex                                          msno  \
# 0              NaN  MXIMDXO0j3UpaT7FvOSGW6Y5zfhlh+xYjTqGoUdMzEE=
# 1              NaN  MXIMDXO0j3UpaT7FvOSGW6Y5zfhlh+xYjTqGoUdMzEE=
# 2              NaN  MXIMDXO0j3UpaT7FvOSGW6Y5zfhlh+xYjTqGoUdMzEE=
# 3              NaN  MXIMDXO0j3UpaT7FvOSGW6Y5zfhlh+xYjTqGoUdMzEE=
# 4              NaN  MXIMDXO0j3UpaT7FvOSGW6Y5zfhlh+xYjTqGoUdMzEE=
#
#                                         song_id      source_type  target  \
# 0  U9kojfZSKaiWOW94PKh1Riyv/zUWxmBRmv0XInQWLGw=  online-playlist       1
# 1  reXuGcEWDDCnL0K3Th//3DFG4S1ACSpJMzA+CFipo1g=  online-playlist       1
# 2  nHr25h3r9uEiX21mU+hJuXhbZUDIZ19z638lGn458hg=  online-playlist       0
# 3  mPfvuBngmcJEuQHhIFSTSO/46BDiQ4sPRJoWipd+ggA=  online-playlist       0
# 4  8lGxKW1C1//LB32ChXt1tRFxD84VbA0Q9MlPJy96A8Y=  online-playlist       1
#
#    weightedRating
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN

# %%
#Applies a sum to the topCustomers after grouping it up by customer_id

tempTopUsersSpending = topUsersSpending.groupby('song_id').sum()[['similarityIndex','weightedRating']]
tempTopUsersSpending.columns = ['sum_similarityIndex','sum_weightedSpending']
tempTopUsersSpending.head()
# Out:
# C:\Users\Shubham Gupta\AppData\Local\Temp\ipykernel_10072\623260759.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   tempTopUsersSpending = topUsersSpending.groupby('song_id').sum()[['similarityIndex','weightedRating']]
#                                               sum_similarityIndex  \
# song_id
# ++7GdTgp8zbQLYOki7hVPEOHpu+KLZClsGrGiEuL2uI=                  0.0
# ++A2uqzDg/vUWu0x/cBalbddrVIJXggKKgQCkEnXmkI=                  0.0
# ++BW3oO/EHKpfAk08rmYFbAWce6sDyL1f4+xhDJibTQ=                  0.0
# ++EBTkZ77PSeSnVQ72CHesRb3907hLqwlRGEZzBNkhs=                  0.0
# ++JV6V/560LsknHy0vuqo5+4O30xpcOsiw0vLsiWeIE=                  0.0
#
#                                               sum_weightedSpending
# song_id
# ++7GdTgp8zbQLYOki7hVPEOHpu+KLZClsGrGiEuL2uI=                   0.0
# ++A2uqzDg/vUWu0x/cBalbddrVIJXggKKgQCkEnXmkI=                   0.0
# ++BW3oO/EHKpfAk08rmYFbAWce6sDyL1f4+xhDJibTQ=                   0.0
# ++EBTkZ77PSeSnVQ72CHesRb3907hLqwlRGEZzBNkhs=                   0.0
# ++JV6V/560LsknHy0vuqo5+4O30xpcOsiw0vLsiWeIE=                   0.0

# %%
#Creates an empty dataframe
recommendation_df = pd.DataFrame()

#Now we take the weighted average
recommendation_df['weighted average recommendation score'] = tempTopUsersSpending['sum_weightedSpending']/tempTopUsersSpending['sum_similarityIndex']
recommendation_df['song_id'] = tempTopUsersSpending.index
recommendation_df.head()
# Out:
#                                               weighted average recommendation score  \
# song_id
# ++7GdTgp8zbQLYOki7hVPEOHpu+KLZClsGrGiEuL2uI=                                    NaN
# ++A2uqzDg/vUWu0x/cBalbddrVIJXggKKgQCkEnXmkI=                                    NaN
# ++BW3oO/EHKpfAk08rmYFbAWce6sDyL1f4+xhDJibTQ=                                    NaN
# ++EBTkZ77PSeSnVQ72CHesRb3907hLqwlRGEZzBNkhs=                                    NaN
# ++JV6V/560LsknHy0vuqo5+4O30xpcOsiw0vLsiWeIE=                                    NaN
#
#                                                                                    song_id
# song_id
# ++7GdTgp8zbQLYOki7hVPEOHpu+KLZClsGrGiEuL2uI=  ++7GdTgp8zbQLYOki7hVPEOHpu+KLZClsGrGiEuL2uI=
# ++A2uqzDg/vUWu0x/cBalbddrVIJXggKKgQCkEnXmkI=  ++A2uqzDg/vUWu0x/cBalbddrVIJXggKKgQCkEnXmkI=
# ++BW3oO/EHKpfAk08rmYFbAWce6sDyL1f4+xhDJibTQ=  ++BW3oO/EHKpfAk08rmYFbAWce6sDyL1f4+xhDJibTQ=
# ++EBTkZ77PSeSnVQ72CHesRb3907hLqwlRGEZzBNkhs=  ++EBTkZ77PSeSnVQ72CHesRb3907hLqwlRGEZzBNkhs=
# ++JV6V/560LsknHy0vuqo5+4O30xpcOsiw0vLsiWeIE=  ++JV6V/560LsknHy0vuqo5+4O30xpcOsiw0vLsiWeIE=

# %% [markdown]
# Now let's sort it and see the top 5 categories that the algorithm recommended!

# %%
#let's sort it and see the top 5 categories that the algorithm recommended

recommendation_df = recommendation_df.sort_values(by='weighted average recommendation score', ascending=False)
recommendation_df.head()
# Out:
#                                               weighted average recommendation score  \
# song_id
# ++7GdTgp8zbQLYOki7hVPEOHpu+KLZClsGrGiEuL2uI=                                    NaN
# ++A2uqzDg/vUWu0x/cBalbddrVIJXggKKgQCkEnXmkI=                                    NaN
# ++BW3oO/EHKpfAk08rmYFbAWce6sDyL1f4+xhDJibTQ=                                    NaN
# ++EBTkZ77PSeSnVQ72CHesRb3907hLqwlRGEZzBNkhs=                                    NaN
# ++JV6V/560LsknHy0vuqo5+4O30xpcOsiw0vLsiWeIE=                                    NaN
#
#                                                                                    song_id
# song_id
# ++7GdTgp8zbQLYOki7hVPEOHpu+KLZClsGrGiEuL2uI=  ++7GdTgp8zbQLYOki7hVPEOHpu+KLZClsGrGiEuL2uI=
# ++A2uqzDg/vUWu0x/cBalbddrVIJXggKKgQCkEnXmkI=  ++A2uqzDg/vUWu0x/cBalbddrVIJXggKKgQCkEnXmkI=
# ++BW3oO/EHKpfAk08rmYFbAWce6sDyL1f4+xhDJibTQ=  ++BW3oO/EHKpfAk08rmYFbAWce6sDyL1f4+xhDJibTQ=
# ++EBTkZ77PSeSnVQ72CHesRb3907hLqwlRGEZzBNkhs=  ++EBTkZ77PSeSnVQ72CHesRb3907hLqwlRGEZzBNkhs=
# ++JV6V/560LsknHy0vuqo5+4O30xpcOsiw0vLsiWeIE=  ++JV6V/560LsknHy0vuqo5+4O30xpcOsiw0vLsiWeIE=

# %%
pred_test = rec_sys_merge.loc[rec_sys_merge['song_id'].isin(recommendation_df.head()['song_id'].tolist())]

# %% [markdown]
# # Evaluation

# %% [markdown]
# To load a dataset from a pandas dataframe, I will need the load_from_df() method. I will also need a Reader object. The dataframe must have three columns, corresponding to the user/customer (raw) ids, the category (raw) ids, and the proportion_spent in this order.

# %%
#Train and test split

from sklearn.model_selection import train_test_split

trainset, testset = train_test_split(rec_sys_merge, test_size=0.2)

# %% [markdown]
# I’ll be using the famous SVD algorithm, as popularized by Simon Funk during the Netflix Prize. SVD is a Matrix Factorization techniques are usually more effective because they allow us to discover the latent features underlying the interactions between users and items.

# %%
#Predictions on the test set (1)
predictions = algo_SVD.test(testset)
predictions[0:5]

# %% [markdown]
# ###Evaluation RMSE
#
# Singular vector decomposition (SVD) shown here employs the use of gradient descent to minimize the squared error between predicted rating and actual rating, eventually getting the best model.

# %%
#accuracy, using RMSE

from surprise import accuracy
accuracy.rmse(predictions)

# %%
#Cross validation

#split the dataset for 5-fold cross-validation, and compute the MAE and RMSE of the SVD algorithm.

from surprise.model_selection import cross_validate

cross_validate(algo, data, measures=['RMSE', 'MAE'], cv=5, verbose=True)

# %%
#make predictions on test set - showing 'actual' and 'cf_predictions' (2)
pred_test = algo_SVD.test(testset)
pred_test = pd.DataFrame(pred_test)
pred_test.drop("details", inplace=True, axis=1)
pred_test.columns = ['msno', 'song_id', 'actual', 'cf_predictions']
pred_test.head()

# %%
#Recmetrics: MSE, RMSE

import recmetrics

#evaluate model with MSE and RMSE
print(recmetrics.mse(pred_test.actual, pred_test.cf_predictions))
print(recmetrics.rmse(pred_test.actual, pred_test.cf_predictions))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10072\1708507237.py in <cell line: 0>()
#       4
#       5 #evaluate model with MSE and RMSE
# ----> 6 print(recmetrics.mse(pred_test.actual, pred_test.cf_predictions))
#       7 print(recmetrics.rmse(pred_test.actual, pred_test.cf_predictions))
#
# ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'actual'

# %%
#create model (matrix of predicted values)
cf_model = pred_test.pivot_table(index='msno', columns='song_id', values='cf_predictions').fillna(0)

# %%
#function for recommended items

def get_users_predictions(customer_id, n, model):
    recommended_items = pd.DataFrame(model.loc[customer_id])
    recommended_items.columns = ["predicted_Cat"]
    recommended_items = recommended_items.sort_values('predicted_Cat', ascending=False)    
    recommended_items = recommended_items.head(n)
    return recommended_items.index.tolist()

# %%
#format test data
pred_test = pred_test.copy().groupby('msno')['song_id'].agg({'actual': (lambda x: list(set(x)))})
#make recommendations for all members in the test data
cf_recs = [] = []
for user in pred_test.index:
    cf_predictions = get_users_predictions(user, 10, cf_model)
    cf_recs.append(cf_predictions)
        
pred_test['cf_predictions'] = cf_recs
pred_test.head()
